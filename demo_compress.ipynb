# %%
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn

from configs.CC import Config
from peleenet import build_net

from utils.core import anchors, init_net, get_dataloader,\
print_info, image_forward, nms_process
from utils.timer import Timer

from layers.functions import Detect, PriorBox
from data import BaseTransform

from tqdm import tqdm
import pickle

# %% [markdown]
# ## Build net

# %%
## Build net

cfgfile = "./configs/Pelee_VOC.py"

cfg = Config.fromfile(cfgfile)
net = build_net('test', cfg.model.input_size, cfg.model)

path2pretrained = "/workspace/raid/data/jgusak/Pelee.Pytorch/Pelee_VOC.pth"
init_net(net, cfg, path2pretrained)

net.eval()
# Out:
# Loading resume network...
# PeleeNet(
#   (features): Sequential(
#     (stemblock): _StemBlock(
#       (stem1): conv_bn_relu(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stem2a): conv_bn_relu(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stem2b): conv_bn_relu(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stem3): conv_bn_relu(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition1): conv_bn_relu(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (transition1_pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(160, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(160, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer4): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(224, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(224, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition2): conv_bn_relu(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (transition2_pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(320, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(320, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer4): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(352, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(352, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer5): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer6): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(416, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(416, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer7): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(448, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(448, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer8): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition3): conv_bn_relu(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (transition3_pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(544, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(544, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(576, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(576, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer4): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(608, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(608, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer5): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(640, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(640, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer6): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(672, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(672, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition4): conv_bn_relu(
#       (conv): Conv2d(704, 704, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (extras): ModuleList(
#     (0): conv_bn_relu(
#       (conv): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): conv_bn_relu(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): conv_bn_relu(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): conv_bn_relu(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): conv_bn_relu(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): conv_bn_relu(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (resblock): ModuleList(
#     (0): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(704, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (2): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (3): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (4): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
#   (loc): ModuleList(
#     (0): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (conf): ModuleList(
#     (0): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (softmax): Softmax()
# )

# %% [markdown]
# ## Compress net (layers from net.features, for example)
#
#     -Noting to compress inside net.loc, net.conf, net.softmax \
#     -one 3x3 conv in each of 5 ResBlock in net.resblock\
#     -one 3x3 conv in net.extras.1, net.extras.3, net.extras.5\
#     -many 3x3 branch1b.conv, branch2b.conv, branch2c.conv in net.features

# %%
import copy
import sys
sys.path.append('/workspace/home/jgusak/musco/')

from model_utils import get_layer_names
from tensor_compression import get_compressed_model
from flopco import FlopCo
# Out:
# Using numpy backend.
# Using pytorch backend.

# %%
layer_names, conv_layer_mask = get_layer_names(net)

fc_layer_mask = (1 - conv_layer_mask).astype(bool)

print(layer_names[conv_layer_mask])
# print(layer_names[fc_layer_mask])
# Out:
# ['features.stemblock.stem1.conv' 'features.stemblock.stem2a.conv'
#  'features.stemblock.stem2b.conv' 'features.stemblock.stem3.conv'
#  'features.denseblock1.denselayer1.branch1a.conv'
#  'features.denseblock1.denselayer1.branch1b.conv'
#  'features.denseblock1.denselayer1.branch2a.conv'
#  'features.denseblock1.denselayer1.branch2b.conv'
#  'features.denseblock1.denselayer1.branch2c.conv'
#  'features.denseblock1.denselayer2.branch1a.conv'
#  'features.denseblock1.denselayer2.branch1b.conv'
#  'features.denseblock1.denselayer2.branch2a.conv'
#  'features.denseblock1.denselayer2.branch2b.conv'
#  'features.denseblock1.denselayer2.branch2c.conv'
#  'features.denseblock1.denselayer3.branch1a.conv'
#  'features.denseblock1.denselayer3.branch1b.conv'
#  'features.denseblock1.denselayer3.branch2a.conv'
#  'features.denseblock1.denselayer3.branch2b.conv'
#  'features.denseblock1.denselayer3.branch2c.conv'
#  'features.transition1.conv'
#  'features.denseblock2.denselayer1.branch1a.conv'
#  'features.denseblock2.denselayer1.branch1b.conv'
#  'features.denseblock2.denselayer1.branch2a.conv'
#  'features.denseblock2.denselayer1.branch2b.conv'
#  'features.denseblock2.denselayer1.branch2c.conv'
#  'features.denseblock2.denselayer2.branch1a.conv'
#  'features.denseblock2.denselayer2.branch1b.conv'
#  'features.denseblock2.denselayer2.branch2a.conv'
#  'features.denseblock2.denselayer2.branch2b.conv'
#  'features.denseblock2.denselayer2.branch2c.conv'
#  'features.denseblock2.denselayer3.branch1a.conv'
#  'features.denseblock2.denselayer3.branch1b.conv'
#  'features.denseblock2.denselayer3.branch2a.conv'
#  'features.denseblock2.denselayer3.branch2b.conv'
#  'features.denseblock2.denselayer3.branch2c.conv'
#  'features.denseblock2.denselayer4.branch1a.conv'
#  'features.denseblock2.denselayer4.branch1b.conv'
#  'features.denseblock2.denselayer4.branch2a.conv'
#  'features.denseblock2.denselayer4.branch2b.conv'
#  'features.denseblock2.denselayer4.branch2c.conv'
#  'features.transition2.conv'
#  'features.denseblock3.denselayer1.branch1a.conv'
#  'features.denseblock3.denselayer1.branch1b.conv'
#  'features.denseblock3.denselayer1.branch2a.conv'
#  'features.denseblock3.denselayer1.branch2b.conv'
#  'features.denseblock3.denselayer1.branch2c.conv'
#  'features.denseblock3.denselayer2.branch1a.conv'
#  'features.denseblock3.denselayer2.branch1b.conv'
#  'features.denseblock3.denselayer2.branch2a.conv'
#  'features.denseblock3.denselayer2.branch2b.conv'
#  'features.denseblock3.denselayer2.branch2c.conv'
#  'features.denseblock3.denselayer3.branch1a.conv'
#  'features.denseblock3.denselayer3.branch1b.conv'
#  'features.denseblock3.denselayer3.branch2a.conv'
#  'features.denseblock3.denselayer3.branch2b.conv'
#  'features.denseblock3.denselayer3.branch2c.conv'
#  'features.denseblock3.denselayer4.branch1a.conv'
#  'features.denseblock3.denselayer4.branch1b.conv'
#  'features.denseblock3.denselayer4.branch2a.conv'
#  'features.denseblock3.denselayer4.branch2b.conv'
#  'features.denseblock3.denselayer4.branch2c.conv'
#  'features.denseblock3.denselayer5.branch1a.conv'
#  'features.denseblock3.denselayer5.branch1b.conv'
#  'features.denseblock3.denselayer5.branch2a.conv'
#  'features.denseblock3.denselayer5.branch2b.conv'
#  'features.denseblock3.denselayer5.branch2c.conv'
#  'features.denseblock3.denselayer6.branch1a.conv'
#  'features.denseblock3.denselayer6.branch1b.conv'
#  'features.denseblock3.denselayer6.branch2a.conv'
#  'features.denseblock3.denselayer6.branch2b.conv'
#  'features.denseblock3.denselayer6.branch2c.conv'
#  'features.denseblock3.denselayer7.branch1a.conv'
#  'features.denseblock3.denselayer7.branch1b.conv'
#  'features.denseblock3.denselayer7.branch2a.conv'
#  'features.denseblock3.denselayer7.branch2b.conv'
#  'features.denseblock3.denselayer7.branch2c.conv'
#  'features.denseblock3.denselayer8.branch1a.conv'
#  'features.denseblock3.denselayer8.branch1b.conv'
#  'features.denseblock3.denselayer8.branch2a.conv'
#  'features.denseblock3.denselayer8.branch2b.conv'
#  'features.denseblock3.denselayer8.branch2c.conv'
#  'features.transition3.conv'
#  'features.denseblock4.denselayer1.branch1a.conv'
#  'features.denseblock4.denselayer1.branch1b.conv'
#  'features.denseblock4.denselayer1.branch2a.conv'
#  'features.denseblock4.denselayer1.branch2b.conv'
#  'features.denseblock4.denselayer1.branch2c.conv'
#  'features.denseblock4.denselayer2.branch1a.conv'
#  'features.denseblock4.denselayer2.branch1b.conv'
#  'features.denseblock4.denselayer2.branch2a.conv'
#  'features.denseblock4.denselayer2.branch2b.conv'
#  'features.denseblock4.denselayer2.branch2c.conv'
#  'features.denseblock4.denselayer3.branch1a.conv'
#  'features.denseblock4.denselayer3.branch1b.conv'
#  'features.denseblock4.denselayer3.branch2a.conv'
#  'features.denseblock4.denselayer3.branch2b.conv'
#  'features.denseblock4.denselayer3.branch2c.conv'
#  'features.denseblock4.denselayer4.branch1a.conv'
#  'features.denseblock4.denselayer4.branch1b.conv'
#  'features.denseblock4.denselayer4.branch2a.conv'
#  'features.denseblock4.denselayer4.branch2b.conv'
#  'features.denseblock4.denselayer4.branch2c.conv'
#  'features.denseblock4.denselayer5.branch1a.conv'
#  'features.denseblock4.denselayer5.branch1b.conv'
#  'features.denseblock4.denselayer5.branch2a.conv'
#  'features.denseblock4.denselayer5.branch2b.conv'
#  'features.denseblock4.denselayer5.branch2c.conv'
#  'features.denseblock4.denselayer6.branch1a.conv'
#  'features.denseblock4.denselayer6.branch1b.conv'
#  'features.denseblock4.denselayer6.branch2a.conv'
#  'features.denseblock4.denselayer6.branch2b.conv'
#  'features.denseblock4.denselayer6.branch2c.conv'
#  'features.transition4.conv' 'extras.0.conv' 'extras.1.conv'
#  'extras.2.conv' 'extras.3.conv' 'extras.4.conv' 'extras.5.conv'
#  'resblock.0.res1a.conv' 'resblock.0.res1b.conv' 'resblock.0.res1c.conv'
#  'resblock.0.res2a.conv' 'resblock.1.res1a.conv' 'resblock.1.res1b.conv'
#  'resblock.1.res1c.conv' 'resblock.1.res2a.conv' 'resblock.2.res1a.conv'
#  'resblock.2.res1b.conv' 'resblock.2.res1c.conv' 'resblock.2.res2a.conv'
#  'resblock.3.res1a.conv' 'resblock.3.res1b.conv' 'resblock.3.res1c.conv'
#  'resblock.3.res2a.conv' 'resblock.4.res1a.conv' 'resblock.4.res1b.conv'
#  'resblock.4.res1c.conv' 'resblock.4.res2a.conv' 'loc.0' 'loc.1' 'loc.2'
#  'loc.3' 'loc.4' 'conf.0' 'conf.1' 'conf.2' 'conf.3' 'conf.4']

# %%
model = copy.deepcopy(net)
compressed_model = get_compressed_model(model,
                                        ranks=[0],
                                        layer_names=['features.denseblock1.denselayer2.branch2b.conv'],
                                        decompositions = ['tucker2'],
                                        vbmf_weaken_factor=1.0)
compressed_model.to('cuda')
# Out:
# Decompose layer features.denseblock1.denselayer2.branch2b.conv
# 	 new rank:  [16, 16]
# PeleeNet(
#   (features): Sequential(
#     (stemblock): _StemBlock(
#       (stem1): conv_bn_relu(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stem2a): conv_bn_relu(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stem2b): conv_bn_relu(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stem3): conv_bn_relu(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Sequential(
#             (conv-0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (conv-1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (conv-2): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition1): conv_bn_relu(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (transition1_pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(160, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(160, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer4): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(224, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(224, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition2): conv_bn_relu(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (transition2_pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(320, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(320, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer4): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(352, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(352, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer5): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer6): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(416, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(416, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer7): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(448, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(448, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer8): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition3): conv_bn_relu(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (transition3_pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer2): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(544, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(544, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer3): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(576, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(576, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer4): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(608, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(608, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer5): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(640, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(640, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (denselayer6): _DenseLayer(
#         (branch1a): conv_bn_relu(
#           (conv): Conv2d(672, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch1b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2a): conv_bn_relu(
#           (conv): Conv2d(672, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2b): conv_bn_relu(
#           (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (branch2c): conv_bn_relu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (transition4): conv_bn_relu(
#       (conv): Conv2d(704, 704, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (extras): ModuleList(
#     (0): conv_bn_relu(
#       (conv): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): conv_bn_relu(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): conv_bn_relu(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): conv_bn_relu(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): conv_bn_relu(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): conv_bn_relu(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (resblock): ModuleList(
#     (0): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(704, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (2): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (3): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (4): ResBlock(
#       (res1a): conv_relu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res1b): conv_relu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (res1c): conv_relu(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (res2a): conv_relu(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
#   (loc): ModuleList(
#     (0): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (conf): ModuleList(
#     (0): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(256, 126, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (softmax): Softmax()
# )

# %%
flopco_m = FlopCo(net.features)
flopco_m.total_flops
# Out:
# 1027096448

# %%
flopco_cm = FlopCo(compressed_model.features)
flopco_cm.total_flops
# Out:
# 1030307712

# %% [markdown]
# ## Save compressed net

# %%
torch.save(compressed_model.state_dict(), '/workspace/raid/data/jgusak/Pelee.Pytorch/Pelee_VOC_compressed.pth')

# %% [markdown]
# ## Draft

# %%
from torchvision.models import resnet18, resnet50
model2 = resnet50()

flopco_m2 = FlopCo(model2)

# %%
flopco_m2.total_flops
# Out:
# 8234241536

# %%
flopco_m2.total_flops/flopco_m.total_flops
# Out:
# 8.017009066708408

# %%
len(model2.layer1), len(model2.layer2), len(model2.layer3), len(model2.layer4)
# Out:
# (3, 4, 6, 3)

# %%
dict(model2.named_children()).keys()
# Out:
# dict_keys(['conv1', 'bn1', 'relu', 'maxpool', 'layer1', 'layer2', 'layer3', 'layer4', 'avgpool', 'fc'])

# %%
model2
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
p = "/workspace/raid/data/jgusak/Pelee.Pytorch/weights/peleenet.pth"

mo = torch.load(p)
type(mo)
# Out:
# collections.OrderedDict
